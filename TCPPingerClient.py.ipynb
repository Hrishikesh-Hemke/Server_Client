# %%
import socket
import time
import random
import string

# Server address and port
server_host = '172.31.0.2'
server_port = 12000

def generate_random_string(length):
    letters = string.ascii_lowercase
    random_string = ''.join(random.choice(letters) for i in range(length))
    return random_string

# Number of messages to send
num_pings = int(input("Enter the number of messages to send: "))

# Create a TCP socket
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# Initialize variables for RTT calculations and packet loss
rtt_times = []
packets_lost = 0
total=0

# Set a timeout for receiving a response (1 second)
client_socket.settimeout(1)

# Connect to the server
client_socket.connect((server_host, server_port))


# Loop for sending pings
for seq in range(1, num_pings + 1):
    # Get the current time before sending the ping
    start_time = time.time()
    
    #Generating rondom lowercase character to ping
    letters = generate_random_string(5)
    
   #Prepare the message to send
    message = f'ping {seq} {start_time} \nMessage Returned: {letters}'
    print('Message Sent:',letters)

       
     
    while True:
        
        # Send the ping message to the server
        client_socket.send(message.encode()) 
        
    
        try:
            # Receive the response from the server
            response = client_socket.recv(1024)

            # Get the current time after receiving the response
            end_time = time.time()

            # Calculate the round-trip time (RTT)
            rtt = end_time - start_time
            rtt_times.append(rtt)

            print(f'{response.decode()} \nRTT: {rtt:.6f} seconds')
            print(end='\n')
            break

        except socket.timeout:
            # Handle timeout (packet loss)
            print(f'Request timed out for PING {seq}\nRetransmitting')
            print(end='\n')
            packets_lost += 1
            
    
# Close the socket
client_socket.close()

# Calculate and print statistics
if len(rtt_times) > 0:
    min_rtt = min(rtt_times)
    max_rtt = max(rtt_times)
    avg_rtt = sum(rtt_times) / len(rtt_times)
    packet_loss_rate = (packets_lost / num_pings) * 100
    print(f'\nPing statistics: Minimum = {min_rtt:.6f} seconds, Maximum = {max_rtt:.6f} seconds, Average = {avg_rtt:.6f} seconds, Packet Loss Rate = {packet_loss_rate:.2f}%')
else:
    print('\nNo successful pings.')
# Out:
# Enter the number of messages to send:  10
# Message Sent: uqvjy
# Request timed out for PING 1
# Retransmitting
#
# PING 1 1694414140.447764
# MESSAGE RETURNED: UQVJY
# RTT: 1.005242 seconds
#
# Message Sent: krmer
# Request timed out for PING 2
# Retransmitting
#
# PING 2 1694414141.4530058
# MESSAGE RETURNED: KRMER
# RTT: 1.004174 seconds
#
# Message Sent: bqxbo
# Request timed out for PING 3
# Retransmitting
#
# Request timed out for PING 3
# Retransmitting
#
# Request timed out for PING 3
# Retransmitting
#
# PING 3 1694414142.4581878
# MESSAGE RETURNED: BQXBO
# RTT: 3.018089 seconds
#
# Message Sent: uxfdw
# PING 4 1694414145.4762769
# MESSAGE RETURNED: UXFDW
# RTT: 0.001027 seconds
#
# Message Sent: wywkk
# Request timed out for PING 5
# Retransmitting
#
# PING 5 1694414145.4773042
# MESSAGE RETURNED: WYWKK
# RTT: 1.014587 seconds
#
# Message Sent: sdsfc
# PING 6 1694414146.4918911
# MESSAGE RETURNED: SDSFC
# RTT: 0.001034 seconds
#
# Message Sent: ksfjw
# PING 7 1694414146.4929256
# MESSAGE RETURNED: KSFJW
# RTT: 0.000965 seconds
#
# Message Sent: cvkat
# PING 8 1694414146.4938905
# MESSAGE RETURNED: CVKAT
# RTT: 0.000000 seconds
#
# Message Sent: qiuoo
# Request timed out for PING 9
# Retransmitting
#
# Request timed out for PING 9
# Retransmitting
#
# Request timed out for PING 9
# Retransmitting
#
# PING 9 1694414146.4938905
# MESSAGE RETURNED: QIUOO
# RTT: 3.029560 seconds
#
# Message Sent: nrsmw
# PING 10 1694414149.5234504
# MESSAGE RETURNED: NRSMW
# RTT: 0.001005 seconds
#
#
# Ping statistics: Minimum = 0.000000 seconds, Maximum = 3.029560 seconds, Average = 0.907568 seconds, Packet Loss Rate = 90.00%
